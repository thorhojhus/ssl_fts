# %%
import pandas as pd
from hurst import compute_Hc
import numpy as np

def analyze_hurst_exponents(dataset_name):
    # Load the dataset
    df = pd.read_csv(f'../data/{dataset_name}.csv')

    # Replace zero values with NaN to avoid division by zero and assign back to the column
    df['OT'] = df['OT'].replace(0, np.nan)

    # Drop rows where 'OT' is NaN
    df.dropna(subset=['OT'], inplace=True)

    # Compute Hurst exponent for different kinds
    H0, c, data = compute_Hc(df['OT'], kind='change')
    H1, c, data = compute_Hc(df['OT'], kind='random_walk')
    
    try:
        H2, c, data = compute_Hc(df['OT'], kind='price')
        H2_output = f"{H2:.4f} - 'price'       : a series is a cumulative product of changes (i.e. np.cumprod(1+epsilon*np.random.randn(...)))"
    except FloatingPointError:
        H2_output = "'price'       : encountered an error, output omitted"
    
    print(f"""H for OT
{H0:.4f} - 'change'      : a series is just random values (i.e. np.random.randn(...))
{H1:.4f} - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
{H2_output}""")

    return df

# %%
analyze_hurst_exponents('ETTm2')
# Out:
# H for OT
# -1.0941 - 'change'      : a series is just random values (i.e. np.random.randn(...))
# 0.2233 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
# 'price'       : encountered an error, output omitted
#                       date       HUFL    HULL       MUFL    MULL    LUFL  \
# 0      2016-07-01 00:00:00  41.130001  12.481  36.535999   9.355   4.424
# 1      2016-07-01 00:15:00  39.622002  11.309  35.543999   8.551   3.209
# 2      2016-07-01 00:30:00  38.868000  10.555  34.365002   7.586   4.435
# 3      2016-07-01 00:45:00  35.518002   9.214  32.569000   8.712   4.435
# 4      2016-07-01 01:00:00  37.528000  10.136  33.936001   7.532   4.435
# ...                    ...        ...     ...        ...     ...     ...
# 69675  2018-06-26 18:45:00  42.722000  12.230  54.014000  12.652 -11.525
# 69676  2018-06-26 19:00:00  38.868000  10.052  49.859001  10.669 -11.525
# ...

# %%
analyze_hurst_exponents('exchange_rate')
# Out:
# H for OT
# 0.4718 - 'change'      : a series is just random values (i.e. np.random.randn(...))
# 0.5002 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
# 0.5697 - 'price'       : a series is a cumulative product of changes (i.e. np.cumprod(1+epsilon*np.random.randn(...)))
#                  date         0         1         2         3         4  \
# 0       1990/1/1 0:00  0.785500  1.611000  0.861698  0.634196  0.211242
# 1       1990/1/2 0:00  0.781800  1.610000  0.861104  0.633513  0.211242
# 2       1990/1/3 0:00  0.786700  1.629300  0.861030  0.648508  0.211242
# 3       1990/1/4 0:00  0.786000  1.637000  0.862069  0.650618  0.211242
# 4       1990/1/5 0:00  0.784900  1.653000  0.861995  0.656254  0.211242
# ...               ...       ...       ...       ...       ...       ...
# 7583   2010/10/6 0:00  0.718494  1.222195  0.737485  0.969974  0.143697
# 7584   2010/10/7 0:00  0.721839  1.223459  0.741155  0.977297  0.143763
# ...

# %%
import pandas as pd
from hurst import compute_Hc
import numpy as np
import nolds

def compute_hurst_exponent(dataset_name):
    # Load the dataset
    df = pd.read_csv(f'../data/{dataset_name}.csv')

    # Identify the last column
    last_column = df.columns[-1]

    # Replace zero values with NaN to avoid division by zero and assign back to the column
    # df[last_column] = df[last_column].replace(0, np.nan)

    # Drop rows where the last column is NaN
    # df.dropna(subset=[last_column], inplace=True)

#     lyap_exp = nolds.lyap_e(df[last_column].dropna().values)
    
#     print(f"""Lyapunov exponent for column {last_column}
# {lyap_exp:.4f}""")

    H1, c, data = compute_Hc(df[last_column], kind='random_walk')
    
    print(f"""H for column {last_column}
{H1:.4f} - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))""")

    return df

# %%
compute_hurst_exponent('electricity')
# Out:
# H for column OT
# 0.2449 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                       date     0      1      2      3      4       5     6  \
# 0      2016-07-01 02:00:00  14.0   69.0  234.0  415.0  215.0  1056.0  29.0
# 1      2016-07-01 03:00:00  18.0   92.0  312.0  556.0  292.0  1363.0  29.0
# 2      2016-07-01 04:00:00  21.0   96.0  312.0  560.0  272.0  1240.0  29.0
# 3      2016-07-01 05:00:00  20.0   92.0  312.0  443.0  213.0   845.0  24.0
# 4      2016-07-01 06:00:00  22.0   91.0  312.0  346.0  190.0   647.0  16.0
# ...                    ...   ...    ...    ...    ...    ...     ...   ...
# 26299  2019-07-01 21:00:00  11.0  116.0    8.0  844.0  384.0  1590.0  51.0
# 26300  2019-07-01 22:00:00  11.0  103.0    8.0  749.0  371.0  1366.0  47.0
# 26301  2019-07-01 23:00:00  12.0   93.0    8.0  650.0  346.0  1282.0  48.0
# 26302  2019-07-02 00:00:00  10.0   92.0    8.0  646.0  349.0  1261.0  48.0
# ...

# %%
compute_hurst_exponent('ETTh1')
# Out:
# H for column OT
# 0.3191 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# 2      2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218
# 3      2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279
# 4      2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279
# ...                    ...     ...    ...    ...    ...    ...    ...
# 17415  2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523
# 17416  2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675
# 17417  2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523
# 17418  2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432
# 17419  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
#
# ...

# %%
compute_hurst_exponent('ETTh2')
# Out:
# H for column OT
# 0.2322 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                       date       HUFL    HULL       MUFL    MULL    LUFL  \
# 0      2016-07-01 00:00:00  41.130001  12.481  36.535999   9.355   4.424
# 1      2016-07-01 01:00:00  37.528000  10.136  33.936001   7.532   4.435
# 2      2016-07-01 02:00:00  37.946999  11.309  35.330002   9.007   2.100
# 3      2016-07-01 03:00:00  38.952000  11.895  35.543999   9.436   3.380
# 4      2016-07-01 04:00:00  38.113998  11.476  35.410000   9.623   2.036
# ...                    ...        ...     ...        ...     ...     ...
# 17415  2018-06-26 15:00:00  39.202999  11.392  49.644001  11.929 -10.331
# 17416  2018-06-26 16:00:00  38.113998  10.974  48.759998  11.366 -10.331
# 17417  2018-06-26 17:00:00  39.622002  10.974  50.609001  11.661 -11.557
# 17418  2018-06-26 18:00:00  43.643002  13.403  54.737000  13.778 -10.299
# ...

# %%
compute_hurst_exponent('ETTm1')
# Out:
# H for column OT
# 0.3471 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 00:15:00   5.760  2.076  1.492  0.426  4.264  1.401
# 2      2016-07-01 00:30:00   5.760  1.942  1.492  0.391  4.234  1.310
# 3      2016-07-01 00:45:00   5.760  1.942  1.492  0.426  4.234  1.310
# 4      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# ...                    ...     ...    ...    ...    ...    ...    ...
# 69675  2018-06-26 18:45:00   9.310  3.550  5.437  1.670  3.868  1.462
# 69676  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
# 69677  2018-06-26 19:15:00  10.784  3.349  7.000  1.635  3.746  1.432
# 69678  2018-06-26 19:30:00  11.655  3.617  7.533  1.706  4.173  1.523
# 69679  2018-06-26 19:45:00  12.994  3.818  8.244  1.777  4.721  1.523
#
# ...

# %%
compute_hurst_exponent('ETTm2')
# Out:
# H for column OT
# 0.2319 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                       date       HUFL    HULL       MUFL    MULL    LUFL  \
# 0      2016-07-01 00:00:00  41.130001  12.481  36.535999   9.355   4.424
# 1      2016-07-01 00:15:00  39.622002  11.309  35.543999   8.551   3.209
# 2      2016-07-01 00:30:00  38.868000  10.555  34.365002   7.586   4.435
# 3      2016-07-01 00:45:00  35.518002   9.214  32.569000   8.712   4.435
# 4      2016-07-01 01:00:00  37.528000  10.136  33.936001   7.532   4.435
# ...                    ...        ...     ...        ...     ...     ...
# 69675  2018-06-26 18:45:00  42.722000  12.230  54.014000  12.652 -11.525
# 69676  2018-06-26 19:00:00  38.868000  10.052  49.859001  10.669 -11.525
# 69677  2018-06-26 19:15:00  39.622002  11.057  50.448002  11.795 -10.299
# 69678  2018-06-26 19:30:00  40.459999  11.392  51.841999  11.929 -11.536
# ...

# %%
compute_hurst_exponent('traffic')
# Out:
# H for column 861
# 0.1637 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                       Date       0       1       2       3       4       5  \
# 0      2015-01-01 00:00:00  0.0048  0.0146  0.0289  0.0142  0.0064  0.0232
# 1      2015-01-01 01:00:00  0.0072  0.0148  0.0350  0.0174  0.0084  0.0240
# 2      2015-01-01 02:00:00  0.0040  0.0101  0.0267  0.0124  0.0049  0.0170
# 3      2015-01-01 03:00:00  0.0039  0.0060  0.0218  0.0090  0.0029  0.0118
# 4      2015-01-01 04:00:00  0.0042  0.0055  0.0191  0.0082  0.0024  0.0095
# ...                    ...     ...     ...     ...     ...     ...     ...
# 17539  2016-12-31 19:00:00  0.0342  0.0332  0.1378  0.0559  0.0165  0.0386
# 17540  2016-12-31 20:00:00  0.0285  0.0253  0.0542  0.0485  0.0131  0.0331
# 17541  2016-12-31 21:00:00  0.0276  0.0257  0.0551  0.0474  0.0121  0.0326
# 17542  2016-12-31 22:00:00  0.0232  0.0229  0.0496  0.0435  0.0119  0.0297
# ...

# %%
compute_hurst_exponent('national_illness')
# Out:
# H for column OT
# 0.3410 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                     date  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  AGE 5-24  \
# 0    2002-01-01 00:00:00        1.222620         1.166680      582       805
# 1    2002-01-08 00:00:00        1.333440         1.216500      683       872
# 2    2002-01-15 00:00:00        1.319290         1.130570      642       878
# 3    2002-01-22 00:00:00        1.494840         1.252460      728      1045
# 4    2002-01-29 00:00:00        1.471950         1.302370      823      1189
# ..                   ...             ...              ...      ...       ...
# 961  2020-06-02 00:00:00        0.839059         0.846722     2756      3528
# 962  2020-06-09 00:00:00        0.895958         0.908885     3203      3778
# 963  2020-06-16 00:00:00        0.910926         0.941625     3478      3796
# 964  2020-06-23 00:00:00        0.946945         0.972185     3734      3818
# ...

# %%
compute_hurst_exponent('weather')
# Out:
# H for column OT
# 0.3249 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                       date  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0      2020-01-01 00:10:00   1008.89      0.71    273.18        -1.33    86.1
# 1      2020-01-01 00:20:00   1008.76      0.75    273.22        -1.44    85.2
# 2      2020-01-01 00:30:00   1008.66      0.73    273.21        -1.48    85.1
# 3      2020-01-01 00:40:00   1008.64      0.37    272.86        -1.64    86.3
# 4      2020-01-01 00:50:00   1008.61      0.33    272.82        -1.50    87.4
# ...                    ...       ...       ...       ...          ...     ...
# 52691  2020-12-31 23:20:00    978.32      2.28    277.16        -0.80    80.0
# 52692  2020-12-31 23:30:00    978.30      2.13    277.01        -0.43    83.1
# 52693  2020-12-31 23:40:00    978.26      1.99    276.88        -0.71    82.2
# ...

# %%
compute_hurst_exponent('exchange_rate')
# Out:
# H for column OT
# 0.5002 - 'random_walk' : a series is a cumulative sum of changes (i.e. np.cumsum(np.random.randn(...)))
#                  date         0         1         2         3         4  \
# 0       1990/1/1 0:00  0.785500  1.611000  0.861698  0.634196  0.211242
# 1       1990/1/2 0:00  0.781800  1.610000  0.861104  0.633513  0.211242
# 2       1990/1/3 0:00  0.786700  1.629300  0.861030  0.648508  0.211242
# 3       1990/1/4 0:00  0.786000  1.637000  0.862069  0.650618  0.211242
# 4       1990/1/5 0:00  0.784900  1.653000  0.861995  0.656254  0.211242
# ...               ...       ...       ...       ...       ...       ...
# 7583   2010/10/6 0:00  0.718494  1.222195  0.737485  0.969974  0.143697
# 7584   2010/10/7 0:00  0.721839  1.223459  0.741155  0.977297  0.143763
# 7585   2010/10/8 0:00  0.723197  1.234111  0.745184  0.984446  0.143997
# 7586   2010/10/9 0:00  0.720825  1.233905  0.744131  0.980344  0.143993
# ...
